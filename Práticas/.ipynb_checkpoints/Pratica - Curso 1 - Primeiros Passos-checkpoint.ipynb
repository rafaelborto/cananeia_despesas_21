# %%
import pandas as pd

# %%
df_desp21 = pd.read_csv("desp21.csv", engine = 'python', sep = ";")
df_desp21
# Out:
#        id_despesa_detalhe  ano_exercicio ds_municipio  \
# 0               501104429           2021     Cananéia
# 1               501104430           2021     Cananéia
# 2               501104837           2021     Cananéia
# 3               501104838           2021     Cananéia
# 4               501104839           2021     Cananéia
# ...                   ...            ...          ...
# 19846           543344437           2021     Cananéia
# 19847           543344439           2021     Cananéia
# 19848           543344441           2021     Cananéia
# 19849           543344445           2021     Cananéia
# 19850           543344454           2021     Cananéia
#
#                                ds_orgao  mes_referencia mes_ref_extenso  \
# 0      PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# 1      PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# 2      PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# ...

# %%
df_desp21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19851 entries, 0 to 19850
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_despesa_detalhe     19851 non-null  int64
#  1   ano_exercicio          19851 non-null  int64
#  2   ds_municipio           19851 non-null  object
#  3   ds_orgao               19851 non-null  object
#  4   mes_referencia         19851 non-null  int64
#  5   mes_ref_extenso        19851 non-null  object
#  6   tp_despesa             19851 non-null  object
#  7   nr_empenho             19851 non-null  object
#  8   identificador_despesa  19851 non-null  object
#  9   ds_despesa             19851 non-null  object
#  10  dt_emissao_despesa     19851 non-null  object
#  11  vl_despesa             19851 non-null  object
#  12  ds_funcao_governo      19851 non-null  object
#  13  ds_subfuncao_governo   19851 non-null  object
# ...
