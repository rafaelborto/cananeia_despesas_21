# %%
import pandas as pd
desp21 = pd.read_csv('desp21.csv', sep = ';')
desp21.head(5)
# Out:
#    id_despesa_detalhe  ano_exercicio ds_municipio  \
# 0           501104429           2021     Cananéia
# 1           501104430           2021     Cananéia
# 2           501104837           2021     Cananéia
# 3           501104838           2021     Cananéia
# 4           501104839           2021     Cananéia
#
#                            ds_orgao  mes_referencia mes_ref_extenso  \
# 0  PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# 1  PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# 2  PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# 3  PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# 4  PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
#
#   tp_despesa nr_empenho                    identificador_despesa  \
# 0  Empenhado    47-2021  CNPJ - PESSOA JURÍDICA - 00985700000182
# 1  Empenhado   173-2021  CNPJ - PESSOA JURÍDICA - 28672201000154
# 2  Empenhado     1-2021  CNPJ - PESSOA JURÍDICA - 23475476000184
# 3  Empenhado     3-2021  CNPJ - PESSOA JURÍDICA - 02558157000162
# 4  Empenhado   400-2021  CNPJ - PESSOA JURÍDICA - 07129517000124
#
#                                           ds_despesa  ...  \
# 0                             IVAN DEL REI CORREA-ME  ...
# 1  MC KLIMKE FERRAGENS E MATERIAIS PARA CONSTRUÇÃ...  ...
# 2                      CÍCERO LINARDO DE SOUZA - MEI  ...
# 3         TELECOMUNICACOES DE SAO PAULO S/A - TELESP  ...
# 4               ARGEMIRO VENANCIO DA COSTA FILHO- ME  ...
#
#        ds_subfuncao_governo cd_programa  \
# 0       ADMINISTRAÇÃO GERAL         101
# 1   ASSISTÊNCIA COMUNITÁRIA         106
# 2       ADMINISTRAÇÃO GERAL         101
# 3  DEFESA DA ORDEM JURÍDICA         101
# 4   ASSISTÊNCIA COMUNITÁRIA         106
#
#                                         ds_programa cd_acao  \
# 0    EFICIÊNCIA E EFICÁCIA NA GESTÃO ADMINISTRATIVA    2101
# 1  SERVIÇOS DE ASSISTÊNCIA E DESENVOLVIMENTO SOCIAL    2126
# 2    EFICIÊNCIA E EFICÁCIA NA GESTÃO ADMINISTRATIVA    2101
# 3    EFICIÊNCIA E EFICÁCIA NA GESTÃO ADMINISTRATIVA    2101
# 4  SERVIÇOS DE ASSISTÊNCIA E DESENVOLVIMENTO SOCIAL    2126
#
#                                      ds_acao  \
# 0  Manutenção das Atividades Administrativas
# 1           Atendimento às Famílias Carentes
# 2  Manutenção das Atividades Administrativas
# 3  Manutenção das Atividades Administrativas
# 4           Atendimento às Famílias Carentes
#
#                                     ds_fonte_recurso  ds_cd_aplicacao_fixo  \
# 0                                            TESOURO          0110 - GERAL
# 1                                            TESOURO          0110 - GERAL
# 2                                            TESOURO          0110 - GERAL
# 3                                            TESOURO          0110 - GERAL
# 4  RECURSOS PRÓPRIOS DE FUNDOS ESPECIAIS DE DESPE...    0100 - GERAL TOTAL
#
#        ds_modalidade_lic                                        ds_elemento  \
# 0  DISPENSA DE LICITAÇÃO    33903039 - MATERIAL PARA MANUTENÇÃO DE VEÍCULOS
# 1  DISPENSA DE LICITAÇÃO          33903026 - MATERIAL ELÉTRICO E ELETRÔNICO
# 2  DISPENSA DE LICITAÇÃO                  33903007 - GÊNEROS DE ALIMENTAÇÃO
# 3   OUTROS/NÃO APLICÁVEL            33903958 - SERVIÇOS DE TELECOMUNICAÇÕES
# 4                 PREGÃO  33903299 - OUTROS MATERIAIS DE DISTRIBUIÇÃO GR...
#
#                                    historico_despesa
# 0  AQUISIÇÃO DE PEÇAS PARA MANUTENÇÃO DE VEICULO,...
# 1                           LÂMPADA DE LED 45W-127 V
# 2       AQUISIÇÃO DE MARMITEX, AQUISIÇÃO DE MARMITEX
# 3  PAGTO DE CONTA TELEFONICA BRASIL ANO DE 2021, ...
# 4  AGUA SANITARIA 2LTS, ALCOOL 70%, DESINFETANTE ...
#
# [5 rows x 23 columns]

# %%
desp21.drop(['ano_exercicio', 'ds_orgao', 'ds_municipio', 'mes_referencia', 'dt_emissao_despesa', 'ds_programa', 
             'ds_fonte_recurso', 'ds_cd_aplicacao_fixo'], axis = 1, inplace = True)

#se eu não especificar o axis, ele vai tentar eliminar da LINHA

desp21.head(10)
# Out:
#    id_despesa_detalhe mes_ref_extenso tp_despesa nr_empenho  \
# 0           501104429         Janeiro  Empenhado    47-2021
# 1           501104430         Janeiro  Empenhado   173-2021
# 2           501104837         Janeiro  Empenhado     1-2021
# 3           501104838         Janeiro  Empenhado     3-2021
# 4           501104839         Janeiro  Empenhado   400-2021
# 5           501105181         Janeiro  Empenhado   288-2021
# 6           501105182         Janeiro  Empenhado    70-2021
# 7           501105190         Janeiro  Empenhado   424-2021
# 8           501105191         Janeiro  Empenhado   161-2021
# 9           501105192         Janeiro  Empenhado    21-2021
#
#                                identificador_despesa  \
# 0            CNPJ - PESSOA JURÍDICA - 00985700000182
# 1            CNPJ - PESSOA JURÍDICA - 28672201000154
# 2            CNPJ - PESSOA JURÍDICA - 23475476000184
# 3            CNPJ - PESSOA JURÍDICA - 02558157000162
# 4            CNPJ - PESSOA JURÍDICA - 07129517000124
# 5                             PESSOA FÍSICA - 315998
# 6            CNPJ - PESSOA JURÍDICA - 43776517000180
# 7  IDENTIFICAÇÃO ESPECIAL - SEM CPF/CNPJ - 000000...
# 8            CNPJ - PESSOA JURÍDICA - 28091870000132
# 9            CNPJ - PESSOA JURÍDICA - 43776517000180
#
#                                           ds_despesa vl_despesa  \
# 0                             IVAN DEL REI CORREA-ME     660,00
# 1  MC KLIMKE FERRAGENS E MATERIAIS PARA CONSTRUÇÃ...     675,00
# 2                      CÍCERO LINARDO DE SOUZA - MEI     504,00
# 3         TELECOMUNICACOES DE SAO PAULO S/A - TELESP    1500,00
# 4               ARGEMIRO VENANCIO DA COSTA FILHO- ME     325,60
# 5                 PRISCILLA APARECIDA DE SOUZA ALVES     400,00
# 6                                             SABESP    1800,00
# 7                                 FOLHA DE PAGAMENTO   22453,50
# 8                   RAQUEL CARVALHO APOLIDORIO LOPES     690,00
# 9                                             SABESP   21000,00
#
#      ds_funcao_governo      ds_subfuncao_governo  cd_programa  cd_acao  \
# 0        ADMINISTRAÇÃO       ADMINISTRAÇÃO GERAL          101     2101
# 1   ASSISTÊNCIA SOCIAL   ASSISTÊNCIA COMUNITÁRIA          106     2126
# 2        ADMINISTRAÇÃO       ADMINISTRAÇÃO GERAL          101     2101
# 3  ESSENCIAL À JUSTIÇA  DEFESA DA ORDEM JURÍDICA          101     2101
# 4   ASSISTÊNCIA SOCIAL   ASSISTÊNCIA COMUNITÁRIA          106     2126
# 5        ADMINISTRAÇÃO       ADMINISTRAÇÃO GERAL          101     2101
# 6  ESSENCIAL À JUSTIÇA  DEFESA DA ORDEM JURÍDICA          101     2101
# 7        ADMINISTRAÇÃO       ADMINISTRAÇÃO GERAL          101     2101
# 8   ASSISTÊNCIA SOCIAL   ASSISTÊNCIA COMUNITÁRIA          106     2126
# 9        ADMINISTRAÇÃO       ADMINISTRAÇÃO GERAL          101     2101
#
#                                      ds_acao      ds_modalidade_lic  \
# 0  Manutenção das Atividades Administrativas  DISPENSA DE LICITAÇÃO
# 1           Atendimento às Famílias Carentes  DISPENSA DE LICITAÇÃO
# 2  Manutenção das Atividades Administrativas  DISPENSA DE LICITAÇÃO
# 3  Manutenção das Atividades Administrativas   OUTROS/NÃO APLICÁVEL
# 4           Atendimento às Famílias Carentes                 PREGÃO
# 5  Manutenção das Atividades Administrativas   OUTROS/NÃO APLICÁVEL
# 6  Manutenção das Atividades Administrativas   OUTROS/NÃO APLICÁVEL
# 7  Manutenção das Atividades Administrativas   OUTROS/NÃO APLICÁVEL
# 8           Atendimento às Famílias Carentes  DISPENSA DE LICITAÇÃO
# 9  Manutenção das Atividades Administrativas   OUTROS/NÃO APLICÁVEL
#
#                                          ds_elemento  \
# 0    33903039 - MATERIAL PARA MANUTENÇÃO DE VEÍCULOS
# 1          33903026 - MATERIAL ELÉTRICO E ELETRÔNICO
# 2                  33903007 - GÊNEROS DE ALIMENTAÇÃO
# 3            33903958 - SERVIÇOS DE TELECOMUNICAÇÕES
# 4  33903299 - OUTROS MATERIAIS DE DISTRIBUIÇÃO GR...
# 5  33903999 - OUTROS SERVIÇOS DE TERCEIROS - PESS...
# 6               33903944 - SERVIÇOS DE ÁGUA E ESGOTO
# 7           31901175 - SUBSÍDIOS - AGENTES POLÍTICOS
# 8  44905206 - APARELHOS E EQUIPAMENTOS DE COMUNIC...
# 9               33903944 - SERVIÇOS DE ÁGUA E ESGOTO
#
#                                    historico_despesa
# 0  AQUISIÇÃO DE PEÇAS PARA MANUTENÇÃO DE VEICULO,...
# 1                           LÂMPADA DE LED 45W-127 V
# 2       AQUISIÇÃO DE MARMITEX, AQUISIÇÃO DE MARMITEX
# 3  PAGTO DE CONTA TELEFONICA BRASIL ANO DE 2021, ...
# 4  AGUA SANITARIA 2LTS, ALCOOL 70%, DESINFETANTE ...
# 5  DESPESA DE PRONTO PAGAMENTO PARA USO DO GABINE...
# 6  FORNECIMENTO DE AGUA E ESGOTO ANO DE 2021, FOR...
# 7  FOLHA DE PAGAMENTO MES DE JANEIRO/21- PREFEITO...
# 8                      TELEFONE SEM FIO COM 3 RAMAIS
# 9  FORNECIMENTO DE AGUA E ESGOTO ANO DE 2021, FOR...

# %%
desp21.groupby(["ds_funcao_governo", "tp_despesa"]).sum()
# Out:
#                                      id_despesa_detalhe  cd_programa  cd_acao
# ds_funcao_governo   tp_despesa
# ADMINISTRAÇÃO       Anulação                37167005065         7070   147133
#                     Empenhado              549192476775       105949  2205220
#                     Valor Liquidado        658825375817       126654  2635976
#                     Valor Pago             771604874639       148066  3081302
# AGRICULTURA         Anulação                 2173339125          420     8428
#                     Empenhado               44078786809         8820   176988
#                     Valor Liquidado         49386588713         9870   198058
#                     Valor Pago              48032019110         9555   191737
# ASSISTÊNCIA SOCIAL  Anulação                33365349438         6678   131714
#                     Empenhado              419786977163        84906  1682871
#                     Valor Liquidado        472957555994        95294  1890025
#                     Valor Pago             465860978230        93598  1856905
# COMÉRCIO E SERVIÇOS Anulação                 9066859690         1768    36091
#                     Empenhado               79678001832        15704   320573
#                     Valor Liquidado         88217037509        17368   354541
#                     Valor Pago              85181137804        16744   341803
# CULTURA             Anulação                10673433035         2080    42440
#                     Empenhado              226681367782        44720   912392
#                     Valor Liquidado        242434937894        47736   973930
#                     Valor Pago             206112050336        40560   827580
# DESPORTO E LAZER    Anulação                 3776533994          728    14742
#                     Empenhado               56697601501        11232   226350
#                     Valor Liquidado         68936558307        13624   274788
#                     Valor Pago              65955180520        13000   262152
# EDUCAÇÃO            Anulação                22942833832         4386    88621
#                     Empenhado              469992408621        90882  1805143
#                     Valor Liquidado        520231740455       100368  2000959
#                     Valor Pago             472810699719        91086  1818320
# ENCARGOS ESPECIAIS  Anulação                  501433603            0        1
#                     Empenhado               47125691992            0       89
#                     Valor Liquidado         46652699927            0       88
#                     Valor Pago              46644619350            0       88
# ESSENCIAL À JUSTIÇA Anulação                 2166221507          404     8404
#                     Empenhado               52334939846        10100   210100
#                     Valor Liquidado         76683229523        14746   306746
#                     Valor Pago              74828996813        14342   298342
# GESTÃO AMBIENTAL    Anulação                 6882102036         1369    27509
#                     Empenhado               62096216582        12398   249058
#                     Valor Liquidado         83298980038        16594   333612
#                     Valor Pago              83001090931        16489   331533
# LEGISLATIVA         Anulação                 7989027771           15    30015
#                     Empenhado               94144658143          180   360180
#                     Valor Liquidado        151597786690          289   578289
#                     Valor Pago             207721506176          396   792396
# SAÚDE               Anulação                21181491726         4120    84608
#                     Empenhado              689927516674       135754  2789076
#                     Valor Liquidado        702528308862       137814  2831298
#                     Valor Pago             667484692994       130501  2680948
# SEGURANÇA PÚBLICA   Anulação                 1061103419          210     4248
#                     Empenhado                8465751641         1680    33984
#                     Valor Liquidado          5848784011         1155    23364
#                     Valor Pago               4240769640          840    16992
# TRANSPORTE          Anulação                 3704404947          735    14875
#                     Empenhado               81844719763        16380   331500
#                     Valor Liquidado         91583307925        18270   369750
#                     Valor Pago              88573756903        17640   357000
# URBANISMO           Anulação                13679996254         2730    53507
#                     Empenhado              272781843315        54600  1089925
#                     Valor Liquidado        294732373219        58800  1175445
#                     Valor Pago             274656682699        54705  1094378

# %% [markdown]
# # Preciso transformar o vl_despesa em float

# %% [markdown]
# In this guide, you’ll see two approaches to convert strings into integers in Pandas DataFrame:
#
# (1) The astype(int) approach:
#
# df['DataFrame Column'] = df['DataFrame Column'].astype(int)
# (2) The to_numeric approach:
#
# df['DataFrame Column'] = pd.to_numeric(df['DataFrame Column'])

# %%
# for i in range(0, desp21['vl_despesa'].shape[0]):
# #     print(desp21['vl_despesa'][i])
# #     s  = pd.Series(list(desp21['vl_despesa'][i].replace(',', '.')))

# # s.astype(int)
# pd.to_numeric(s)

# s = desp21['vl_despesa']
# s.replace(',', '.', inplace = True)
# s

# s = desp21.applymap(lambda x: str(x.replace(',','.')))

# %%
# s = desp21['vl_despesa']
# pd.to_numeric(s)

# # convert all columns of DataFrame
# df = df.apply(pd.to_numeric) # convert all columns of DataFrame

# # convert just columns "a" and "b"
# df[["a", "b"]] = df[["a", "b"]].apply(pd.to_numeric)

# %%
s = desp21['vl_despesa']

# %%
s1 = pd.to_numeric(s.replace(',', '.', inplace = True))
