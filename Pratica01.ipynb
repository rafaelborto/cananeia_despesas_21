# %%
import pandas as pd

# %%
df_desp21 = pd.read_csv("desp21.csv", engine = 'python', sep = ";")
df_desp21
# Out:
#        id_despesa_detalhe  ano_exercicio ds_municipio  \
# 0               501104429           2021     Cananéia
# 1               501104430           2021     Cananéia
# 2               501104837           2021     Cananéia
# 3               501104838           2021     Cananéia
# 4               501104839           2021     Cananéia
# ...                   ...            ...          ...
# 19846           543344437           2021     Cananéia
# 19847           543344439           2021     Cananéia
# 19848           543344441           2021     Cananéia
# 19849           543344445           2021     Cananéia
# 19850           543344454           2021     Cananéia
#
#                                ds_orgao  mes_referencia mes_ref_extenso  \
# 0      PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# 1      PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# 2      PREFEITURA MUNICIPAL DE CANANÉIA               1         Janeiro
# ...

# %%
df_desp21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19851 entries, 0 to 19850
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_despesa_detalhe     19851 non-null  int64
#  1   ano_exercicio          19851 non-null  int64
#  2   ds_municipio           19851 non-null  object
#  3   ds_orgao               19851 non-null  object
#  4   mes_referencia         19851 non-null  int64
#  5   mes_ref_extenso        19851 non-null  object
#  6   tp_despesa             19851 non-null  object
#  7   nr_empenho             19851 non-null  object
#  8   identificador_despesa  19851 non-null  object
#  9   ds_despesa             19851 non-null  object
#  10  dt_emissao_despesa     19851 non-null  object
#  11  vl_despesa             19851 non-null  object
#  12  ds_funcao_governo      19851 non-null  object
#  13  ds_subfuncao_governo   19851 non-null  object
# ...

# %%
credores = list(df_desp21['ds_despesa'].drop_duplicates())
credores
# Out:
# ['IVAN DEL REI CORREA-ME',
#  'MC KLIMKE FERRAGENS E MATERIAIS PARA CONSTRUÇÃO EI',
#  'CÍCERO LINARDO DE SOUZA - MEI',
#  'TELECOMUNICACOES DE SAO PAULO S/A - TELESP',
#  'ARGEMIRO VENANCIO DA COSTA FILHO- ME',
#  'PRISCILLA APARECIDA DE SOUZA ALVES',
#  'SABESP',
#  'FOLHA DE PAGAMENTO',
#  'RAQUEL CARVALHO APOLIDORIO LOPES',
#  'INSS FOLHA',
#  'COMPANHIA DE DES. HAB. DO EST. DE SP - CDHU',
#  'ULTRACOM COMERCIO E SERVIÇOS LTDA',
#  'VS CARD ADMINISTRADORA DE CARTOES LTDA',
#  'CONSORCIO INTER SAUDE VRIBEIRA',
#  'RONIE PETERSON RAMPONI - ME',
#  'DINA MARA BARREIRA DE OLIVEIRA',
#  'ANGELA DIAS CARVALHO-ME',
#  'AUTO POSTO RETIRO DAS CARAVELAS LTDA',
#  'LAERCIO GOMES JUNIOR-ME',
#  'ELEKTRO-ELETRICIDADE E SERVICOS LTDA',
#  'FGTS - EDUCACAO',
#  'FP-SAUDE',
#  'DELANIA FRANCISCA DA ROCHA',
#  'SOLDA ACO COMERCIAL LTDA',
#  'EDINA MARIA TEIXEIRA',
#  'CERTISIGN CERTIFICADORA DIGITAL  S.A.',
#  'JORNAL GAZETA DA GRANDE SAOPAULO LTDA',
#  'AIRTON JOSE SPINA REGISTRO-ME',
# ...

# %%
df_desp21.drop(df_desp21.columns.difference(['id_despesa_detalhe', 'mes_ref_extenso', 'tp_despesa', 'identificador_despesa', 'ds_despesa', 'vl_despesa', 'ds_funcao_governo',  'ds_subfuncao_governo', 'ds_programa', 'ds_acao', 'ds_fonte_recurso', 'historico_despesa']), 1, inplace=True)
# Out:
# C:\Users\Intel\AppData\Local\Temp/ipykernel_8480/4022256770.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_desp21.drop(df_desp21.columns.difference(['id_despesa_detalhe', 'mes_ref_extenso', 'tp_despesa', 'identificador_despesa', 'ds_despesa', 'vl_despesa', 'ds_funcao_governo',  'ds_subfuncao_governo', 'ds_programa', 'ds_acao', 'ds_fonte_recurso', 'historico_despesa']), 1, inplace=True)

# %%
df_desp21
# Out:
#        id_despesa_detalhe mes_ref_extenso       tp_despesa  \
# 0               501104429         Janeiro        Empenhado
# 1               501104430         Janeiro        Empenhado
# 2               501104837         Janeiro        Empenhado
# 3               501104838         Janeiro        Empenhado
# 4               501104839         Janeiro        Empenhado
# ...                   ...             ...              ...
# 19846           543344437        Dezembro  Valor Liquidado
# 19847           543344439        Dezembro  Valor Liquidado
# 19848           543344441        Dezembro  Valor Liquidado
# 19849           543344445        Dezembro  Valor Liquidado
# 19850           543344454        Dezembro  Valor Liquidado
#
#                                    identificador_despesa  \
# 0                CNPJ - PESSOA JURÍDICA - 00985700000182
# 1                CNPJ - PESSOA JURÍDICA - 28672201000154
# 2                CNPJ - PESSOA JURÍDICA - 23475476000184
# ...

# %%
funcao = list(df_desp21['ds_funcao_governo'].unique())
funcao
# Out:
# ['ADMINISTRAÇÃO',
#  'ASSISTÊNCIA SOCIAL',
#  'ESSENCIAL À JUSTIÇA',
#  'URBANISMO',
#  'GESTÃO AMBIENTAL',
#  'EDUCAÇÃO',
#  'SAÚDE',
#  'CULTURA',
#  'COMÉRCIO E SERVIÇOS',
#  'LEGISLATIVA',
#  'TRANSPORTE',
#  'AGRICULTURA',
#  'DESPORTO E LAZER',
#  'ENCARGOS ESPECIAIS',
#  'SEGURANÇA PÚBLICA']

# %%
sub_funcao = list(df_desp21['ds_subfuncao_governo'].unique())
sub_funcao
# Out:
# ['ADMINISTRAÇÃO GERAL',
#  'ASSISTÊNCIA COMUNITÁRIA',
#  'DEFESA DA ORDEM JURÍDICA',
#  'ADMINISTRAÇÃO FINANCEIRA',
#  'SERVIÇOS URBNOS',
#  'CONTROLE AMBIENTAL',
#  'EDUCAÇÃO INFANTIL',
#  'ENSINO FUNDAMENTAL',
#  'ATENÇÃO BÁSICA',
#  'ASSISTÊNCIA HOSPITALAR E AMBULATORIAL',
#  'DIFUSÃO CULTURAL',
#  'TURISMO',
#  'AÇÃO LEGISLATIVA',
#  'ASSISTÊNCIA À CRIANÇA E AO ADOSLESCENTE',
#  'TRANSPORTE RODOVIÁRIO',
#  'PROMOÇÃO DA PRODUÇÃO AGROPECUÁRIA',
#  'VIGILÂNCIA SANITÁRIA',
#  'DESPORTO COMUNITÁRIO',
#  'SERVIÇO DA DÍVIDA INTERNA',
#  'ASSISTÊNCIA AO IDOSO',
#  'ENSINO SUPERIOR',
#  'DEFESA CIVIL',
#  'ASSISTÊNCIA AO PORTADOR DE DEFICIÊNCIA',
#  'ALIMENTAÇÃO E NUTRIÇÃO',
#  'FORMAÇÃO DE RECURSOS HUMANOS',
#  'INFRA-ESTRUTURA URBANA',
#  'ENSINO PROFISSIONAL']

# %%
saude = ['SAÚDE']
dados_saude_isin = df_desp21['ds_funcao_governo'].isin(saude)

# %%
dados_saude = df_desp21[dados_saude_isin]

# %%
dados_saude
# Out:
#        id_despesa_detalhe mes_ref_extenso       tp_despesa  \
# 33              501105720         Janeiro        Empenhado
# 34              501105721         Janeiro        Empenhado
# 35              501105722         Janeiro        Empenhado
# 36              501105723         Janeiro        Empenhado
# 37              501105724         Janeiro        Empenhado
# ...                   ...             ...              ...
# 19830           543344397        Dezembro  Valor Liquidado
# 19833           543344405        Dezembro  Valor Liquidado
# 19837           543344411        Dezembro  Valor Liquidado
# 19843           543344426        Dezembro  Valor Liquidado
# 19848           543344441        Dezembro  Valor Liquidado
#
#                                    identificador_despesa  \
# 33     IDENTIFICAÇÃO ESPECIAL - SEM CPF/CNPJ - 000000...
# 34               CNPJ - PESSOA JURÍDICA - 07129517000124
# 35     IDENTIFICAÇÃO ESPECIAL - SEM CPF/CNPJ - 000000...
# ...

# %%
dados_saude.to_csv('desp21_saude.csv', sep = ';', index = False)
